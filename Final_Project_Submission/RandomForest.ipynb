# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import KFold, GridSearchCV

from imblearn.over_sampling import SMOTE

import sklearn

plt.rcParams["figure.figsize"] = (10, 10)
plt.rcParams["font.size"] = 15

# %%
steam_df = pd.read_csv("Data/steam/games-features-edit.csv")

# %%
def select_genres(genres_list, df):
	if len(genres_list) == 2:
		df = df[(df['Genre'] == 'GenreIs' + genres_list[0]) | (df['Genre'] == 'GenreIs' + genres_list[1])]
	elif len(genres_list) == 3:
		df = df[(df['Genre'] == 'GenreIs' + genres_list[0]) | (df['Genre'] == 'GenreIs' + genres_list[1]) | (df['Genre'] == 'GenreIs' + genres_list[2])]
	elif len(genres_list) == 4:
		df = df[(df['Genre'] == 'GenreIs' + genres_list[0]) | (df['Genre'] == 'GenreIs' + genres_list[1]) | (df['Genre'] == 'GenreIs' + genres_list[2]) | (df['Genre'] == 'GenreIs' + genres_list[3])]

	return df

# %%
#make a new dataframe with only the ResponseName, ReleaseDate, Metacritic, RecommendationCount, IsFree, and PriceInitial
newDF = steam_df[['ResponseName', 'ReleaseDate', 'Metacritic', 'RecommendationCount', 'IsFree', 'PriceInitial']]

genres = ["GenreIsIndie","GenreIsAction","GenreIsAdventure","GenreIsCasual","GenreIsStrategy","GenreIsRPG","GenreIsSimulation","GenreIsEarlyAccess","GenreIsFreeToPlay","GenreIsSports","GenreIsRacing","GenreIsMassivelyMultiplayer"]
temp = []

rows_genres = []

for index, row in steam_df.iterrows():
	for genre in genres:
		if row[genre] == 1:
			temp.append(genre)
	if len(temp)==1:
		rows_genres.append(temp[0])
	temp = []
	

genresDF = pd.DataFrame(rows_genres, columns = ['Genre'], dtype=str)
df = pd.concat([newDF.copy(), genresDF], axis=1)
df = df[df['Metacritic'] != 0]
df.dropna(subset=['Genre', 'RecommendationCount', 'PriceInitial', 'Metacritic'], inplace=True)

#replace the GenreIs with nothing
df['Genre'] = df['Genre'].str.replace('GenreIs', '')
print(len(df))

genresDF = df.groupby('Genre').size().reset_index(name='counts')
genresDF = genresDF.sort_values(by=['Genre'], ascending=True)

genresDF.plot.bar(x='Genre', y='counts', rot=90, title='Number of Games in Each Genre', fontsize=13, ylabel='Number of Games', legend=False)
df.sort_values(by=['Genre'], inplace=True)


x_tick_labels = df['Genre'].unique().tolist()
df['Genre'] = pd.factorize(df['Genre'])[0]

df.plot.scatter(x='Genre', y='PriceInitial', rot=90, title='Price vs Genre', fontsize=13, ylabel='Price', legend=False)
plt.xticks(np.arange(0, len(x_tick_labels), step=1), x_tick_labels, rotation=90)
plt.show()

df.plot.scatter(x='Genre', y='Metacritic', rot=90, title='Metacritic Score vs Genre', fontsize=13, ylabel='Metacritic Score', legend=False)
plt.xticks(np.arange(0, len(x_tick_labels), step=1), x_tick_labels, rotation=90)
plt.show()

df.plot.scatter(x='Genre', y='RecommendationCount', rot=90, title='Recommendation Count vs Genre', fontsize=13, ylabel='Recommendation Count', legend=False)
plt.xticks(np.arange(0, len(x_tick_labels), step=1), x_tick_labels, rotation=90)
plt.show()


def init_df(genres_to_use, rows_genres, df):
	# print((rows_genres))
	genresDF = pd.DataFrame(rows_genres, columns = ['Genre'], dtype=str)
	genresDF = select_genres(genres_to_use, genresDF)

	df = pd.concat([df, genresDF], axis=1)
	df = df.dropna(subset=['Genre'])
	df = df[df['Metacritic'] != 0]
	df.dropna(subset=['Genre', 'RecommendationCount', 'PriceInitial', 'Metacritic'], inplace=True)

	# print(len(df['Genre']))

	return df
# Out:
# 1363

# %%
def plot_genres(df):
    #plot the genres and their recommendation counts
    fig, ax = plt.subplots(1,3)
    ax[0].scatter(df['Genre'], df['PriceInitial'])
    ax[0].set_xlabel('Genre')
    ax[0].set_ylabel('Price ($)')
    ax[1].scatter(df['Genre'], df['RecommendationCount'])
    ax[1].set_xlabel('Genre')
    ax[1].set_ylabel('Recommendation Count')
    ax[2].scatter(df['Genre'], df['Metacritic'])
    ax[2].set_xlabel('Genre')
    ax[2].set_ylabel('Metacritic Score')
    plt.show()

# %%
#split the data into training and testing sets
def train_set(df):
    X = df[['Metacritic', 'RecommendationCount', 'PriceInitial']]
    y = df['Genre']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, train_size=0.8, random_state=42)

    sm = SMOTE(random_state=42)
    X_train, y_train = sm.fit_resample(X_train, y_train)

    # create a k-fold cross validation iterator
    kfold = KFold(n_splits=5, random_state=42, shuffle=True)

    # define the grid of hyperparameters to search over
    param_grid = {
        "n_estimators": [100, 200, 300, 400, 500],
        "max_depth": [5, 10, 15, 20, 25],
        "min_samples_split": [2, 5, 10, 15, 20],
        "random_state": [42]
    }

    # create the random forest classifier
    clf = RandomForestClassifier()

    # create a grid search object to find the best hyperparameters
    grid_search = GridSearchCV(estimator=clf, param_grid=param_grid, cv=kfold, n_jobs=-1)

    # fit the grid search on the data
    grid_search.fit(X_train, y_train)


    # print the best hyperparameters found
    return grid_search.best_estimator_, X_test, y_test, X_train, y_train

# %%
def random_forest(genres_to_use, rows_genres, newDF):
    df = init_df(genres_to_use, rows_genres, newDF)
    
    rfc, X_test, y_test, X_train, y_train = train_set(df)
    cf = RandomForestClassifier(n_estimators=rfc.n_estimators, random_state=rfc.random_state, max_depth=rfc.max_depth, min_samples_split=rfc.min_samples_split)

    abc = AdaBoostClassifier(estimator=cf, n_estimators=100, learning_rate=1, random_state=42)
    cf.fit(X_train, y_train)
    abc.fit(X_train, y_train)
    base_train = accuracy_score(y_train, cf.predict(X_train))
    base_test = accuracy_score(y_test, cf.predict(X_test))

    ada_train = accuracy_score(y_train, abc.predict(X_train))
    ada_test = accuracy_score(y_test, abc.predict(X_test))

    est = cf.estimators_[0]
    t = tree.export_text(est, feature_names=['Metacritic', 'RecommendationCount', 'PriceInitial'])
    print(t)
    return base_train, base_test, ada_train, ada_test

# %%
big_genres = ['Action', 'Adventure', 'Casual', 'Indie', 'Strategy']
base_train_acc = []
ada_train_acc = []
base_test_acc = []
ada_test_acc = []
for genre in big_genres:
    for genre2 in big_genres:
        if genre < genre2:
            print(f'{genre} vs {genre2}')
            train1, test1, train2, test2 = random_forest([genre, genre2], rows_genres, newDF)
            base_train_acc.append(train1)
            base_test_acc.append(test1)
            ada_train_acc.append(train2)
            ada_test_acc.append(test2)
            print()



# Define the training and testing accuracies
# Out:
# Action vs Adventure
# |--- Metacritic <= 86.50
# |   |--- RecommendationCount <= 107.00
# |   |   |--- PriceInitial <= 2.49
# |   |   |   |--- class: 1.0
# |   |   |--- PriceInitial >  2.49
# |   |   |   |--- PriceInitial <= 8.11
# |   |   |   |   |--- PriceInitial <= 6.14
# |   |   |   |   |   |--- Metacritic <= 71.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- Metacritic >  71.50
# |   |   |   |   |   |   |--- Metacritic <= 80.00
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- Metacritic >  80.00
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- PriceInitial >  6.14
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- PriceInitial >  8.11
# |   |   |   |   |--- Metacritic <= 77.00
# |   |   |   |   |   |--- PriceInitial <= 13.99
# |   |   |   |   |   |   |--- PriceInitial <= 10.28
# |   |   |   |   |   |   |   |--- Metacritic <= 53.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Metacritic >  53.50
# |   |   |   |   |   |   |   |   |--- Metacritic <= 72.00
# |   |   |   |   |   |   |   |   |   |--- Metacritic <= 66.50
# |   |   |   |   |   |   |   |   |   |   |--- Metacritic <= 57.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- Metacritic >  57.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- Metacritic >  66.50
# |   |   |   |   |   |   |   |   |   |   |--- Metacritic <= 68.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- Metacritic >  68.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- Metacritic >  72.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- PriceInitial >  10.28
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- PriceInitial >  13.99
# |   |   |   |   |   |   |--- Metacritic <= 69.50
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- Metacritic >  69.50
# |   |   |   |   |   |   |   |--- Metacritic <= 74.50
# |   |   |   |   |   |   |   |   |--- PriceInitial <= 19.99
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- PriceInitial >  19.99
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- Metacritic >  74.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- Metacritic >  77.00
# |   |   |   |   |   |--- Metacritic <= 84.50
# |   |   |   |   |   |   |--- PriceInitial <= 11.49
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- PriceInitial >  11.49
# |   |   |   |   |   |   |   |--- Metacritic <= 81.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- Metacritic >  81.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- Metacritic >  84.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |--- RecommendationCount >  107.00
# |   |   |--- PriceInitial <= 19.97
# |   |   |   |--- Metacritic <= 71.50
# |   |   |   |   |--- PriceInitial <= 10.19
# |   |   |   |   |   |--- Metacritic <= 69.50
# |   |   |   |   |   |   |--- RecommendationCount <= 186.50
# |   |   |   |   |   |   |   |--- PriceInitial <= 9.63
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- PriceInitial >  9.63
# |   |   |   |   |   |   |   |   |--- RecommendationCount <= 140.50
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 117.50
# |   |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 110.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  110.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  117.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- RecommendationCount >  140.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- RecommendationCount >  186.50
# |   |   |   |   |   |   |   |--- PriceInitial <= 8.99
# |   |   |   |   |   |   |   |   |--- RecommendationCount <= 6692.00
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 466.00
# |   |   |   |   |   |   |   |   |   |   |--- Metacritic <= 66.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Metacritic >  66.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  466.00
# |   |   |   |   |   |   |   |   |   |   |--- Metacritic <= 66.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- Metacritic >  66.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- RecommendationCount >  6692.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- PriceInitial >  8.99
# |   |   |   |   |   |   |   |   |--- RecommendationCount <= 364.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- RecommendationCount >  364.50
# |   |   |   |   |   |   |   |   |   |--- Metacritic <= 68.50
# |   |   |   |   |   |   |   |   |   |   |--- Metacritic <= 66.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- Metacritic >  66.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- Metacritic >  68.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- Metacritic >  69.50
# |   |   |   |   |   |   |--- Metacritic <= 70.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- Metacritic >  70.50
# |   |   |   |   |   |   |   |--- RecommendationCount <= 1729.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- RecommendationCount >  1729.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- PriceInitial >  10.19
# |   |   |   |   |   |--- Metacritic <= 67.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- Metacritic >  67.50
# |   |   |   |   |   |   |--- RecommendationCount <= 1411.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- RecommendationCount >  1411.50
# |   |   |   |   |   |   |   |--- PriceInitial <= 14.83
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- PriceInitial >  14.83
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- Metacritic >  71.50
# |   |   |   |   |--- RecommendationCount <= 169.50
# |   |   |   |   |   |--- PriceInitial <= 7.49
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- PriceInitial >  7.49
# |   |   |   |   |   |   |--- Metacritic <= 77.50
# |   |   |   |   |   |   |   |--- Metacritic <= 74.50
# |   |   |   |   |   |   |   |   |--- Metacritic <= 73.00
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 148.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  148.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- Metacritic >  73.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- Metacritic >  74.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- Metacritic >  77.50
# |   |   |   |   |   |   |   |--- PriceInitial <= 10.85
# |   |   |   |   |   |   |   |   |--- Metacritic <= 83.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- Metacritic >  83.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- PriceInitial >  10.85
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- RecommendationCount >  169.50
# |   |   |   |   |   |--- PriceInitial <= 6.24
# |   |   |   |   |   |   |--- RecommendationCount <= 28204.50
# |   |   |   |   |   |   |   |--- RecommendationCount <= 4081.50
# |   |   |   |   |   |   |   |   |--- PriceInitial <= 2.00
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 2424.50
# |   |   |   |   |   |   |   |   |   |   |--- Metacritic <= 78.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- Metacritic >  78.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  2424.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- PriceInitial >  2.00
# |   |   |   |   |   |   |   |   |   |--- Metacritic <= 79.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Metacritic >  79.50
# |   |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 1305.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  1305.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- RecommendationCount >  4081.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- RecommendationCount >  28204.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- PriceInitial >  6.24
# |   |   |   |   |   |   |--- RecommendationCount <= 283.50
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- RecommendationCount >  283.50
# |   |   |   |   |   |   |   |--- Metacritic <= 73.50
# |   |   |   |   |   |   |   |   |--- RecommendationCount <= 2459.00
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 1125.50
# |   |   |   |   |   |   |   |   |   |   |--- PriceInitial <= 9.49
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- PriceInitial >  9.49
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  1125.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- RecommendationCount >  2459.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Metacritic >  73.50
# |   |   |   |   |   |   |   |   |--- PriceInitial <= 13.79
# |   |   |   |   |   |   |   |   |   |--- PriceInitial <= 8.77
# |   |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 324.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  324.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- PriceInitial >  8.77
# |   |   |   |   |   |   |   |   |   |   |--- PriceInitial <= 9.43
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- PriceInitial >  9.43
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- PriceInitial >  13.79
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 14218.50
# |   |   |   |   |   |   |   |   |   |   |--- Metacritic <= 77.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Metacritic >  77.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  14218.50
# |   |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 20162.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  20162.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |--- PriceInitial >  19.97
# |   |   |   |--- RecommendationCount <= 3290.50
# |   |   |   |   |--- Metacritic <= 79.50
# |   |   |   |   |   |--- Metacritic <= 64.50
# |   |   |   |   |   |   |--- PriceInitial <= 22.49
# |   |   |   |   |   |   |   |--- Metacritic <= 53.50
# |   |   |   |   |   |   |   |   |--- RecommendationCount <= 214.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- RecommendationCount >  214.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Metacritic >  53.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- PriceInitial >  22.49
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- Metacritic >  64.50
# |   |   |   |   |   |   |--- PriceInitial <= 60.44
# |   |   |   |   |   |   |   |--- RecommendationCount <= 1438.00
# |   |   |   |   |   |   |   |   |--- RecommendationCount <= 248.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- RecommendationCount >  248.50
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 411.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  411.00
# |   |   |   |   |   |   |   |   |   |   |--- Metacritic <= 68.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- Metacritic >  68.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- RecommendationCount >  1438.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- PriceInitial >  60.44
# |   |   |   |   |   |   |   |--- PriceInitial <= 115.44
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- PriceInitial >  115.44
# |   |   |   |   |   |   |   |   |--- Metacritic <= 76.50
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 1050.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  1050.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Metacritic >  76.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- Metacritic >  79.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- RecommendationCount >  3290.50
# |   |   |   |   |--- PriceInitial <= 20.71
# |   |   |   |   |   |--- Metacritic <= 78.00
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- Metacritic >  78.00
# |   |   |   |   |   |   |--- RecommendationCount <= 4422.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- RecommendationCount >  4422.50
# |   |   |   |   |   |   |   |--- Metacritic <= 79.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Metacritic >  79.50
# |   |   |   |   |   |   |   |   |--- Metacritic <= 81.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- Metacritic >  81.00
# |   |   |   |   |   |   |   |   |   |--- Metacritic <= 84.50
# |   |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 13379.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  13379.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- Metacritic >  84.50
# |   |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 6599.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  6599.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |--- PriceInitial >  20.71
# |   |   |   |   |   |--- Metacritic <= 72.00
# |   |   |   |   |   |   |--- RecommendationCount <= 6827.00
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- RecommendationCount >  6827.00
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- Metacritic >  72.00
# |   |   |   |   |   |   |--- RecommendationCount <= 10766.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- RecommendationCount >  10766.50
# |   |   |   |   |   |   |   |--- RecommendationCount <= 12616.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- RecommendationCount >  12616.00
# |   |   |   |   |   |   |   |   |--- RecommendationCount <= 17530.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- RecommendationCount >  17530.00
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 21692.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  21692.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |--- Metacritic >  86.50
# |   |--- PriceInitial <= 20.89
# |   |   |--- RecommendationCount <= 794.00
# |   |   |   |--- RecommendationCount <= 516.50
# |   |   |   |   |--- class: 0.0
# |   |   |   |--- RecommendationCount >  516.50
# |   |   |   |   |--- class: 1.0
# |   |   |--- RecommendationCount >  794.00
# |   |   |   |--- Metacritic <= 91.50
# |   |   |   |   |--- PriceInitial <= 12.49
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- PriceInitial >  12.49
# |   |   |   |   |   |--- PriceInitial <= 17.49
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- PriceInitial >  17.49
# |   |   |   |   |   |   |--- RecommendationCount <= 2498.50
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- RecommendationCount >  2498.50
# |   |   |   |   |   |   |   |--- RecommendationCount <= 4207.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- RecommendationCount >  4207.50
# |   |   |   |   |   |   |   |   |--- Metacritic <= 88.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Metacritic >  88.50
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 8386.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  8386.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- Metacritic >  91.50
# |   |   |   |   |--- class: 0.0
# |   |--- PriceInitial >  20.89
# |   |   |--- class: 1.0
#
#
# Action vs Casual
# |--- Metacritic <= 65.50
# |   |--- RecommendationCount <= 170.00
# |   |   |--- PriceInitial <= 39.99
# |   |   |   |--- PriceInitial <= 11.15
# |   |   |   |   |--- PriceInitial <= 7.49
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- PriceInitial >  7.49
# |   |   |   |   |   |--- Metacritic <= 62.50
# |   |   |   |   |   |   |--- Metacritic <= 49.50
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- Metacritic >  49.50
# |   |   |   |   |   |   |   |--- Metacritic <= 58.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Metacritic >  58.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- Metacritic >  62.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- PriceInitial >  11.15
# |   |   |   |   |--- PriceInitial <= 14.49
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- PriceInitial >  14.49
# |   |   |   |   |   |--- RecommendationCount <= 59.00
# |   |   |   |   |   |   |--- Metacritic <= 46.50
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- Metacritic >  46.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- RecommendationCount >  59.00
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |--- PriceInitial >  39.99
# |   |   |   |--- class: 0.0
# |   |--- RecommendationCount >  170.00
# |   |   |--- RecommendationCount <= 1136.50
# |   |   |   |--- RecommendationCount <= 587.00
# |   |   |   |   |--- Metacritic <= 53.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- Metacritic >  53.50
# |   |   |   |   |   |--- RecommendationCount <= 436.50
# |   |   |   |   |   |   |--- PriceInitial <= 8.63
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- PriceInitial >  8.63
# |   |   |   |   |   |   |   |--- RecommendationCount <= 214.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- RecommendationCount >  214.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- RecommendationCount >  436.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- RecommendationCount >  587.00
# |   |   |   |   |--- RecommendationCount <= 644.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- RecommendationCount >  644.50
# |   |   |   |   |   |--- Metacritic <= 46.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- Metacritic >  46.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |--- RecommendationCount >  1136.50
# |   |   |   |--- PriceInitial <= 24.99
# |   |   |   |   |--- class: 0.0
# |   |   |   |--- PriceInitial >  24.99
# |   |   |   |   |--- class: 0.0
# |--- Metacritic >  65.50
# |   |--- PriceInitial <= 19.90
# |   |   |--- Metacritic <= 73.50
# |   |   |   |--- Metacritic <= 68.50
# |   |   |   |   |--- RecommendationCount <= 2935.00
# |   |   |   |   |   |--- RecommendationCount <= 2057.00
# |   |   |   |   |   |   |--- PriceInitial <= 12.49
# |   |   |   |   |   |   |   |--- RecommendationCount <= 953.50
# |   |   |   |   |   |   |   |   |--- RecommendationCount <= 66.00
# |   |   |   |   |   |   |   |   |   |--- Metacritic <= 67.50
# |   |   |   |   |   |   |   |   |   |   |--- Metacritic <= 66.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- Metacritic >  66.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Metacritic >  67.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- RecommendationCount >  66.00
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 146.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  146.50
# |   |   |   |   |   |   |   |   |   |   |--- PriceInitial <= 2.49
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- PriceInitial >  2.49
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- RecommendationCount >  953.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- PriceInitial >  12.49
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- RecommendationCount >  2057.00
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- RecommendationCount >  2935.00
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- Metacritic >  68.50
# |   |   |   |   |--- RecommendationCount <= 644.50
# |   |   |   |   |   |--- PriceInitial <= 2.51
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- PriceInitial >  2.51
# |   |   |   |   |   |   |--- PriceInitial <= 14.21
# |   |   |   |   |   |   |   |--- PriceInitial <= 7.19
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- PriceInitial >  7.19
# |   |   |   |   |   |   |   |   |--- RecommendationCount <= 299.50
# |   |   |   |   |   |   |   |   |   |--- PriceInitial <= 9.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- PriceInitial >  9.18
# |   |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 294.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  294.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- RecommendationCount >  299.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- PriceInitial >  14.21
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- RecommendationCount >  644.50
# |   |   |   |   |   |--- PriceInitial <= 15.49
# |   |   |   |   |   |   |--- RecommendationCount <= 1393.50
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- RecommendationCount >  1393.50
# |   |   |   |   |   |   |   |--- PriceInitial <= 6.49
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- PriceInitial >  6.49
# |   |   |   |   |   |   |   |   |--- RecommendationCount <= 1870.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- RecommendationCount >  1870.50
# |   |   |   |   |   |   |   |   |   |--- PriceInitial <= 8.99
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- PriceInitial >  8.99
# |   |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 2730.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  2730.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |--- PriceInitial >  15.49
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |--- Metacritic >  73.50
# |   |   |   |--- PriceInitial <= 10.00
# |   |   |   |   |--- PriceInitial <= 4.49
# |   |   |   |   |   |--- RecommendationCount <= 23874.50
# |   |   |   |   |   |   |--- RecommendationCount <= 3886.00
# |   |   |   |   |   |   |   |--- Metacritic <= 78.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Metacritic >  78.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- RecommendationCount >  3886.00
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- RecommendationCount >  23874.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- PriceInitial >  4.49
# |   |   |   |   |   |--- Metacritic <= 83.50
# |   |   |   |   |   |   |--- PriceInitial <= 6.06
# |   |   |   |   |   |   |   |--- Metacritic <= 79.50
# |   |   |   |   |   |   |   |   |--- Metacritic <= 75.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- Metacritic >  75.50
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 156.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  156.50
# |   |   |   |   |   |   |   |   |   |   |--- Metacritic <= 76.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- Metacritic >  76.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- Metacritic >  79.50
# |   |   |   |   |   |   |   |   |--- RecommendationCount <= 1175.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- RecommendationCount >  1175.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- PriceInitial >  6.06
# |   |   |   |   |   |   |   |--- Metacritic <= 75.50
# |   |   |   |   |   |   |   |   |--- PriceInitial <= 8.99
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- PriceInitial >  8.99
# |   |   |   |   |   |   |   |   |   |--- Metacritic <= 74.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Metacritic >  74.50
# |   |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 1408.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  1408.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Metacritic >  75.50
# |   |   |   |   |   |   |   |   |--- RecommendationCount <= 2120.50
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 1889.50
# |   |   |   |   |   |   |   |   |   |   |--- PriceInitial <= 6.31
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- PriceInitial >  6.31
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  1889.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- RecommendationCount >  2120.50
# |   |   |   |   |   |   |   |   |   |--- Metacritic <= 79.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- Metacritic >  79.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- Metacritic >  83.50
# |   |   |   |   |   |   |--- PriceInitial <= 8.99
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- PriceInitial >  8.99
# |   |   |   |   |   |   |   |--- Metacritic <= 90.00
# |   |   |   |   |   |   |   |   |--- RecommendationCount <= 4599.00
# |   |   |   |   |   |   |   |   |   |--- Metacritic <= 86.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Metacritic >  86.50
# |   |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 347.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  347.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- RecommendationCount >  4599.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- Metacritic >  90.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- PriceInitial >  10.00
# |   |   |   |   |--- PriceInitial <= 15.35
# |   |   |   |   |   |--- PriceInitial <= 14.94
# |   |   |   |   |   |   |--- PriceInitial <= 12.09
# |   |   |   |   |   |   |   |--- PriceInitial <= 11.68
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- PriceInitial >  11.68
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- PriceInitial >  12.09
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- PriceInitial >  14.94
# |   |   |   |   |   |   |--- Metacritic <= 75.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- Metacritic >  75.50
# |   |   |   |   |   |   |   |--- Metacritic <= 86.50
# |   |   |   |   |   |   |   |   |--- RecommendationCount <= 2442.00
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 415.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  415.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- RecommendationCount >  2442.00
# |   |   |   |   |   |   |   |   |   |--- Metacritic <= 85.50
# |   |   |   |   |   |   |   |   |   |   |--- Metacritic <= 76.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- Metacritic >  76.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- Metacritic >  85.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Metacritic >  86.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- PriceInitial >  15.35
# |   |   |   |   |   |--- class: 1.0
# |   |--- PriceInitial >  19.90
# |   |   |--- Metacritic <= 92.50
# |   |   |   |--- PriceInitial <= 32.49
# |   |   |   |   |--- Metacritic <= 90.00
# |   |   |   |   |   |--- RecommendationCount <= 7067.50
# |   |   |   |   |   |   |--- Metacritic <= 71.50
# |   |   |   |   |   |   |   |--- RecommendationCount <= 71.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- RecommendationCount >  71.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- Metacritic >  71.50
# |   |   |   |   |   |   |   |--- Metacritic <= 75.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- Metacritic >  75.50
# |   |   |   |   |   |   |   |   |--- Metacritic <= 78.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Metacritic >  78.00
# |   |   |   |   |   |   |   |   |   |--- PriceInitial <= 21.02
# |   |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 286.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  286.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- PriceInitial >  21.02
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- RecommendationCount >  7067.50
# |   |   |   |   |   |   |--- RecommendationCount <= 14437.50
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- RecommendationCount >  14437.50
# |   |   |   |   |   |   |   |--- Metacritic <= 87.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Metacritic >  87.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- Metacritic >  90.00
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- PriceInitial >  32.49
# |   |   |   |   |--- Metacritic <= 68.00
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- Metacritic >  68.00
# |   |   |   |   |   |--- class: 1.0
# |   |   |--- Metacritic >  92.50
# |   |   |   |--- class: 0.0
#
#
# Action vs Indie
# |--- Metacritic <= 79.50
# |   |--- RecommendationCount <= 1516.00
# |   |   |--- PriceInitial <= 19.69
# |   |   |   |--- PriceInitial <= 10.44
# |   |   |   |   |--- PriceInitial <= 8.83
# |   |   |   |   |   |--- Metacritic <= 66.50
# |   |   |   |   |   |   |--- Metacritic <= 64.50
# |   |   |   |   |   |   |   |--- Metacritic <= 62.50
# |   |   |   |   |   |   |   |   |--- PriceInitial <= 7.38
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 105.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  105.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- PriceInitial >  7.38
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 850.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  850.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Metacritic >  62.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- Metacritic >  64.50
# |   |   |   |   |   |   |   |--- Metacritic <= 65.50
# |   |   |   |   |   |   |   |   |--- PriceInitial <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- PriceInitial >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Metacritic >  65.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- Metacritic >  66.50
# |   |   |   |   |   |   |--- PriceInitial <= 7.07
# |   |   |   |   |   |   |   |--- Metacritic <= 75.50
# |   |   |   |   |   |   |   |   |--- PriceInitial <= 6.88
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 642.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  642.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- PriceInitial >  6.88
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Metacritic >  75.50
# |   |   |   |   |   |   |   |   |--- PriceInitial <= 5.73
# |   |   |   |   |   |   |   |   |   |--- PriceInitial <= 2.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- PriceInitial >  2.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- PriceInitial >  5.73
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- PriceInitial >  7.07
# |   |   |   |   |   |   |   |--- Metacritic <= 73.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- Metacritic >  73.50
# |   |   |   |   |   |   |   |   |--- RecommendationCount <= 288.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- RecommendationCount >  288.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- PriceInitial >  8.83
# |   |   |   |   |   |--- RecommendationCount <= 127.50
# |   |   |   |   |   |   |--- Metacritic <= 70.00
# |   |   |   |   |   |   |   |--- Metacritic <= 57.50
# |   |   |   |   |   |   |   |   |--- RecommendationCount <= 52.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- RecommendationCount >  52.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- Metacritic >  57.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- Metacritic >  70.00
# |   |   |   |   |   |   |   |--- Metacritic <= 73.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- Metacritic >  73.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- RecommendationCount >  127.50
# |   |   |   |   |   |   |--- RecommendationCount <= 393.50
# |   |   |   |   |   |   |   |--- RecommendationCount <= 153.50
# |   |   |   |   |   |   |   |   |--- RecommendationCount <= 134.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- RecommendationCount >  134.50
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 139.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  139.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- RecommendationCount >  153.50
# |   |   |   |   |   |   |   |   |--- RecommendationCount <= 344.50
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 289.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  289.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- RecommendationCount >  344.50
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 381.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  381.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- RecommendationCount >  393.50
# |   |   |   |   |   |   |   |--- PriceInitial <= 9.64
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- PriceInitial >  9.64
# |   |   |   |   |   |   |   |   |--- RecommendationCount <= 690.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- RecommendationCount >  690.50
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 717.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  717.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- PriceInitial >  10.44
# |   |   |   |   |--- RecommendationCount <= 54.50
# |   |   |   |   |   |--- PriceInitial <= 14.98
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- PriceInitial >  14.98
# |   |   |   |   |   |   |--- Metacritic <= 72.00
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- Metacritic >  72.00
# |   |   |   |   |   |   |   |--- PriceInitial <= 15.50
# |   |   |   |   |   |   |   |   |--- Metacritic <= 76.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- Metacritic >  76.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- PriceInitial >  15.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- RecommendationCount >  54.50
# |   |   |   |   |   |--- RecommendationCount <= 719.00
# |   |   |   |   |   |   |--- PriceInitial <= 14.16
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- PriceInitial >  14.16
# |   |   |   |   |   |   |   |--- PriceInitial <= 16.89
# |   |   |   |   |   |   |   |   |--- Metacritic <= 67.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- Metacritic >  67.00
# |   |   |   |   |   |   |   |   |   |--- Metacritic <= 74.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Metacritic >  74.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- PriceInitial >  16.89
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- RecommendationCount >  719.00
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |--- PriceInitial >  19.69
# |   |   |   |--- RecommendationCount <= 719.00
# |   |   |   |   |--- RecommendationCount <= 131.50
# |   |   |   |   |   |--- PriceInitial <= 24.99
# |   |   |   |   |   |   |--- RecommendationCount <= 60.00
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- RecommendationCount >  60.00
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- PriceInitial >  24.99
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- RecommendationCount >  131.50
# |   |   |   |   |   |--- RecommendationCount <= 296.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- RecommendationCount >  296.50
# |   |   |   |   |   |   |--- Metacritic <= 58.00
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- Metacritic >  58.00
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- RecommendationCount >  719.00
# |   |   |   |   |--- RecommendationCount <= 1427.50
# |   |   |   |   |   |--- Metacritic <= 74.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- Metacritic >  74.50
# |   |   |   |   |   |   |--- Metacritic <= 76.00
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- Metacritic >  76.00
# |   |   |   |   |   |   |   |--- RecommendationCount <= 856.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- RecommendationCount >  856.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- RecommendationCount >  1427.50
# |   |   |   |   |   |--- class: 0.0
# |   |--- RecommendationCount >  1516.00
# |   |   |--- PriceInitial <= 10.35
# |   |   |   |--- PriceInitial <= 4.45
# |   |   |   |   |--- RecommendationCount <= 16239.50
# |   |   |   |   |   |--- Metacritic <= 63.00
# |   |   |   |   |   |   |--- Metacritic <= 48.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- Metacritic >  48.50
# |   |   |   |   |   |   |   |--- Metacritic <= 52.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Metacritic >  52.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- Metacritic >  63.00
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- RecommendationCount >  16239.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- PriceInitial >  4.45
# |   |   |   |   |--- PriceInitial <= 8.99
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- PriceInitial >  8.99
# |   |   |   |   |   |--- Metacritic <= 77.50
# |   |   |   |   |   |   |--- Metacritic <= 66.50
# |   |   |   |   |   |   |   |--- Metacritic <= 62.50
# |   |   |   |   |   |   |   |   |--- Metacritic <= 58.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Metacritic >  58.00
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 2420.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  2420.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Metacritic >  62.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- Metacritic >  66.50
# |   |   |   |   |   |   |   |--- RecommendationCount <= 3628.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- RecommendationCount >  3628.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- Metacritic >  77.50
# |   |   |   |   |   |   |--- RecommendationCount <= 1932.50
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- RecommendationCount >  1932.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |--- PriceInitial >  10.35
# |   |   |   |--- PriceInitial <= 14.40
# |   |   |   |   |--- class: 1.0
# |   |   |   |--- PriceInitial >  14.40
# |   |   |   |   |--- Metacritic <= 70.50
# |   |   |   |   |   |--- Metacritic <= 56.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- Metacritic >  56.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- Metacritic >  70.50
# |   |   |   |   |   |--- Metacritic <= 78.50
# |   |   |   |   |   |   |--- Metacritic <= 75.00
# |   |   |   |   |   |   |   |--- RecommendationCount <= 11872.50
# |   |   |   |   |   |   |   |   |--- RecommendationCount <= 3416.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- RecommendationCount >  3416.00
# |   |   |   |   |   |   |   |   |   |--- PriceInitial <= 20.51
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- PriceInitial >  20.51
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- RecommendationCount >  11872.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- Metacritic >  75.00
# |   |   |   |   |   |   |   |--- PriceInitial <= 17.49
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- PriceInitial >  17.49
# |   |   |   |   |   |   |   |   |--- RecommendationCount <= 12287.00
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 4042.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  4042.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- RecommendationCount >  12287.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- Metacritic >  78.50
# |   |   |   |   |   |   |--- PriceInitial <= 17.96
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- PriceInitial >  17.96
# |   |   |   |   |   |   |   |--- RecommendationCount <= 4152.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- RecommendationCount >  4152.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |--- Metacritic >  79.50
# |   |--- Metacritic <= 92.50
# |   |   |--- RecommendationCount <= 8321.50
# |   |   |   |--- PriceInitial <= 10.80
# |   |   |   |   |--- RecommendationCount <= 528.00
# |   |   |   |   |   |--- PriceInitial <= 6.10
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- PriceInitial >  6.10
# |   |   |   |   |   |   |--- RecommendationCount <= 52.00
# |   |   |   |   |   |   |   |--- PriceInitial <= 8.49
# |   |   |   |   |   |   |   |   |--- Metacritic <= 80.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- Metacritic >  80.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- PriceInitial >  8.49
# |   |   |   |   |   |   |   |   |--- Metacritic <= 81.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- Metacritic >  81.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- RecommendationCount >  52.00
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- RecommendationCount >  528.00
# |   |   |   |   |   |--- RecommendationCount <= 1315.50
# |   |   |   |   |   |   |--- RecommendationCount <= 1061.00
# |   |   |   |   |   |   |   |--- PriceInitial <= 2.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- PriceInitial >  2.00
# |   |   |   |   |   |   |   |   |--- PriceInitial <= 9.49
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- PriceInitial >  9.49
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 863.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  863.00
# ...
# |   |   |   |   |--- PriceInitial >  22.49
# |   |   |   |   |   |--- PriceInitial <= 27.49
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- PriceInitial >  27.49
# |   |   |   |   |   |   |--- Metacritic <= 81.50
# |   |   |   |   |   |   |   |--- RecommendationCount <= 5894.00
# |   |   |   |   |   |   |   |   |--- Metacritic <= 76.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Metacritic >  76.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- RecommendationCount >  5894.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- Metacritic >  81.50
# |   |   |   |   |   |   |   |--- class: 0.0
#
#
# Casual vs Indie
# |--- Metacritic <= 83.50
# |   |--- RecommendationCount <= 210.00
# |   |   |--- PriceInitial <= 1.00
# |   |   |   |--- class: 1.0
# |   |   |--- PriceInitial >  1.00
# |   |   |   |--- PriceInitial <= 6.49
# |   |   |   |   |--- class: 0.0
# |   |   |   |--- PriceInitial >  6.49
# |   |   |   |   |--- PriceInitial <= 27.49
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- PriceInitial >  27.49
# |   |   |   |   |   |--- class: 0.0
# |   |--- RecommendationCount >  210.00
# |   |   |--- Metacritic <= 53.50
# |   |   |   |--- class: 0.0
# |   |   |--- Metacritic >  53.50
# |   |   |   |--- Metacritic <= 69.50
# |   |   |   |   |--- Metacritic <= 68.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- Metacritic >  68.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- Metacritic >  69.50
# |   |   |   |   |--- PriceInitial <= 22.49
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- PriceInitial >  22.49
# |   |   |   |   |   |--- class: 1.0
# |--- Metacritic >  83.50
# |   |--- RecommendationCount <= 8377.50
# |   |   |--- RecommendationCount <= 865.50
# |   |   |   |--- class: 0.0
# |   |   |--- RecommendationCount >  865.50
# |   |   |   |--- class: 0.0
# |   |--- RecommendationCount >  8377.50
# |   |   |--- class: 1.0
#
#
# Casual vs Strategy
# |--- Metacritic <= 90.50
# |   |--- RecommendationCount <= 6942.00
# |   |   |--- PriceInitial <= 15.49
# |   |   |   |--- PriceInitial <= 3.99
# |   |   |   |   |--- PriceInitial <= 1.00
# |   |   |   |   |   |--- Metacritic <= 70.00
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- Metacritic >  70.00
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- PriceInitial >  1.00
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- PriceInitial >  3.99
# |   |   |   |   |--- Metacritic <= 73.50
# |   |   |   |   |   |--- Metacritic <= 72.50
# |   |   |   |   |   |   |--- PriceInitial <= 11.49
# |   |   |   |   |   |   |   |--- RecommendationCount <= 121.50
# |   |   |   |   |   |   |   |   |--- RecommendationCount <= 51.00
# |   |   |   |   |   |   |   |   |   |--- Metacritic <= 68.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Metacritic >  68.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- RecommendationCount >  51.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- RecommendationCount >  121.50
# |   |   |   |   |   |   |   |   |--- PriceInitial <= 5.49
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 801.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  801.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- PriceInitial >  5.49
# |   |   |   |   |   |   |   |   |   |--- PriceInitial <= 6.99
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- PriceInitial >  6.99
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- PriceInitial >  11.49
# |   |   |   |   |   |   |   |--- Metacritic <= 51.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Metacritic >  51.00
# |   |   |   |   |   |   |   |   |--- PriceInitial <= 13.99
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- PriceInitial >  13.99
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 2781.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  2781.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- Metacritic >  72.50
# |   |   |   |   |   |   |--- RecommendationCount <= 244.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- RecommendationCount >  244.50
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- Metacritic >  73.50
# |   |   |   |   |   |--- PriceInitial <= 12.44
# |   |   |   |   |   |   |--- PriceInitial <= 9.49
# |   |   |   |   |   |   |   |--- Metacritic <= 74.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- Metacritic >  74.50
# |   |   |   |   |   |   |   |   |--- Metacritic <= 75.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Metacritic >  75.50
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 1569.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  1569.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- PriceInitial >  9.49
# |   |   |   |   |   |   |   |--- Metacritic <= 82.50
# |   |   |   |   |   |   |   |   |--- Metacritic <= 76.50
# |   |   |   |   |   |   |   |   |   |--- Metacritic <= 75.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- Metacritic >  75.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- Metacritic >  76.50
# |   |   |   |   |   |   |   |   |   |--- Metacritic <= 77.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Metacritic >  77.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- Metacritic >  82.50
# |   |   |   |   |   |   |   |   |--- Metacritic <= 87.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- Metacritic >  87.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- PriceInitial >  12.44
# |   |   |   |   |   |   |--- PriceInitial <= 14.94
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- PriceInitial >  14.94
# |   |   |   |   |   |   |   |--- Metacritic <= 86.50
# |   |   |   |   |   |   |   |   |--- RecommendationCount <= 271.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- RecommendationCount >  271.50
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 431.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  431.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Metacritic >  86.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |--- PriceInitial >  15.49
# |   |   |   |--- RecommendationCount <= 6009.50
# |   |   |   |   |--- RecommendationCount <= 150.50
# |   |   |   |   |   |--- Metacritic <= 43.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- Metacritic >  43.50
# |   |   |   |   |   |   |--- PriceInitial <= 24.99
# |   |   |   |   |   |   |   |--- RecommendationCount <= 125.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- RecommendationCount >  125.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- PriceInitial >  24.99
# |   |   |   |   |   |   |   |--- PriceInitial <= 37.49
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- PriceInitial >  37.49
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- RecommendationCount >  150.50
# |   |   |   |   |   |--- RecommendationCount <= 1315.50
# |   |   |   |   |   |   |--- PriceInitial <= 20.14
# |   |   |   |   |   |   |   |--- RecommendationCount <= 533.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- RecommendationCount >  533.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- PriceInitial >  20.14
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- RecommendationCount >  1315.50
# |   |   |   |   |   |   |--- Metacritic <= 68.00
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- Metacritic >  68.00
# |   |   |   |   |   |   |   |--- PriceInitial <= 24.57
# |   |   |   |   |   |   |   |   |--- PriceInitial <= 19.32
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- PriceInitial >  19.32
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount <= 1624.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- RecommendationCount >  1624.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- PriceInitial >  24.57
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- RecommendationCount >  6009.50
# |   |   |   |   |--- class: 1.0
# |   |--- RecommendationCount >  6942.00
# |   |   |--- RecommendationCount <= 8024.50
# |   |   |   |--- class: 1.0
# |   |   |--- RecommendationCount >  8024.50
# |   |   |   |--- Metacritic <= 74.50
# |   |   |   |   |--- class: 1.0
# |   |   |   |--- Metacritic >  74.50
# |   |   |   |   |--- Metacritic <= 78.00
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- Metacritic >  78.00
# |   |   |   |   |   |--- PriceInitial <= 4.99
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- PriceInitial >  4.99
# |   |   |   |   |   |   |--- Metacritic <= 88.50
# |   |   |   |   |   |   |   |--- Metacritic <= 86.50
# |   |   |   |   |   |   |   |   |--- RecommendationCount <= 10962.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- RecommendationCount >  10962.00
# |   |   |   |   |   |   |   |   |   |--- Metacritic <= 85.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- Metacritic >  85.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- Metacritic >  86.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- Metacritic >  88.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |--- Metacritic >  90.50
# |   |--- RecommendationCount <= 4039.00
# |   |   |--- class: 0.0
# |   |--- RecommendationCount >  4039.00
# |   |   |--- class: 0.0
#
#
# Indie vs Strategy
# |--- Metacritic <= 83.50
# |   |--- RecommendationCount <= 218.00
# |   |   |--- PriceInitial <= 2.49
# |   |   |   |--- class: 0.0
# |   |   |--- PriceInitial >  2.49
# |   |   |   |--- PriceInitial <= 13.03
# |   |   |   |   |--- PriceInitial <= 7.49
# |   |   |   |   |   |--- Metacritic <= 44.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- Metacritic >  44.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- PriceInitial >  7.49
# |   |   |   |   |   |--- Metacritic <= 73.50
# |   |   |   |   |   |   |--- Metacritic <= 52.00
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- Metacritic >  52.00
# |   |   |   |   |   |   |   |--- PriceInitial <= 11.49
# |   |   |   |   |   |   |   |   |--- RecommendationCount <= 105.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- RecommendationCount >  105.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- PriceInitial >  11.49
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- Metacritic >  73.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- PriceInitial >  13.03
# |   |   |   |   |--- RecommendationCount <= 147.50
# |   |   |   |   |   |--- Metacritic <= 74.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- Metacritic >  74.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- RecommendationCount >  147.50
# |   |   |   |   |   |--- class: 1.0
# |   |--- RecommendationCount >  218.00
# |   |   |--- PriceInitial <= 10.49
# |   |   |   |--- PriceInitial <= 9.93
# |   |   |   |   |--- Metacritic <= 62.00
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- Metacritic >  62.00
# |   |   |   |   |   |--- PriceInitial <= 5.06
# |   |   |   |   |   |   |--- RecommendationCount <= 1782.00
# |   |   |   |   |   |   |   |--- PriceInitial <= 4.49
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- PriceInitial >  4.49
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- RecommendationCount >  1782.00
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- PriceInitial >  5.06
# |   |   |   |   |   |   |--- PriceInitial <= 7.98
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- PriceInitial >  7.98
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- PriceInitial >  9.93
# |   |   |   |   |--- Metacritic <= 73.50
# |   |   |   |   |   |--- RecommendationCount <= 255.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- RecommendationCount >  255.50
# |   |   |   |   |   |   |--- RecommendationCount <= 727.50
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- RecommendationCount >  727.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- Metacritic >  73.50
# |   |   |   |   |   |--- Metacritic <= 80.50
# |   |   |   |   |   |   |--- Metacritic <= 75.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- Metacritic >  75.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- Metacritic >  80.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |--- PriceInitial >  10.49
# |   |   |   |--- PriceInitial <= 14.87
# |   |   |   |   |--- class: 0.0
# |   |   |   |--- PriceInitial >  14.87
# |   |   |   |   |--- PriceInitial <= 21.47
# |   |   |   |   |   |--- RecommendationCount <= 3137.50
# |   |   |   |   |   |   |--- PriceInitial <= 15.16
# |   |   |   |   |   |   |   |--- Metacritic <= 76.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Metacritic >  76.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- PriceInitial >  15.16
# |   |   |   |   |   |   |   |--- Metacritic <= 79.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- Metacritic >  79.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- RecommendationCount >  3137.50
# |   |   |   |   |   |   |--- PriceInitial <= 18.84
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- PriceInitial >  18.84
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- PriceInitial >  21.47
# |   |   |   |   |   |--- RecommendationCount <= 18251.00
# |   |   |   |   |   |   |--- Metacritic <= 78.00
# |   |   |   |   |   |   |   |--- PriceInitial <= 34.99
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- PriceInitial >  34.99
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- Metacritic >  78.00
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- RecommendationCount >  18251.00
# |   |   |   |   |   |   |--- class: 0.0
# |--- Metacritic >  83.50
# |   |--- RecommendationCount <= 8620.00
# |   |   |--- RecommendationCount <= 475.50
# |   |   |   |--- class: 1.0
# |   |   |--- RecommendationCount >  475.50
# |   |   |   |--- RecommendationCount <= 541.50
# |   |   |   |   |--- class: 0.0
# |   |   |   |--- RecommendationCount >  541.50
# |   |   |   |   |--- PriceInitial <= 7.99
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- PriceInitial >  7.99
# |   |   |   |   |   |--- RecommendationCount <= 1028.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- RecommendationCount >  1028.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |--- RecommendationCount >  8620.00
# |   |   |--- class: 0.0

# %%
plt.figure(figsize=(10, 7))
plt.bar(range(1, 11), base_train_acc, width=0.4, label='Base')
# plt.bar(range(1, 11), ada_train_acc, bottom=base_train_acc, label='AdaBoost')
plt.bar([x + 0.4 for x in range(1, 11)], ada_train_acc, width=0.4, label='AdaBoost')

# Set the x-axis labels
plt.xticks(np.arange(1, 11, 1), ['Action vs Adventure', 'Action vs Casual', 'Action vs Indie', 'Action vs Strategy', 'Adventure vs Casual', 'Adventure vs Indie', 'Adventure vs Strategy', 'Casual vs Indie', 'Casual vs Strategy', 'Indie vs Strategy'], rotation=45)
plt.ylabel('Accuracy')
# Add a legend and a title
plt.legend()
plt.title('Training Accuracies')

# Show the plot
plt.show()

plt.figure(figsize=(10, 7))
plt.bar(range(1, 11), base_test_acc, width=0.4, label='Base')
# plt.bar(range(1, 11), ada_train_acc, bottom=base_train_acc, label='AdaBoost')
plt.bar([x + 0.4 for x in range(1, 11)], ada_test_acc, width=0.4, label='AdaBoost')

# Set the x-axis labels
plt.xticks(np.arange(1, 11, 1), ['Action vs Adventure', 'Action vs Casual', 'Action vs Indie', 'Action vs Strategy', 'Adventure vs Casual', 'Adventure vs Indie', 'Adventure vs Strategy', 'Casual vs Indie', 'Casual vs Strategy', 'Indie vs Strategy'], rotation=45)
plt.ylabel('Accuracy')
# Add a legend and a title
plt.legend()
plt.title('Testing Accuracies')

#draw a line at 0.5
plt.axhline(y=0.5, color='r', linestyle='-')
# Show the plot
plt.show()
# Out:
# [0.983271375464684, 0.9540441176470589, 0.9743589743589743, 0.8444444444444444, 0.9033333333333333, 0.99, 0.9551282051282052, 0.7465277777777778, 0.9363057324840764, 0.8726708074534162]
# [0.9869888475836431, 0.9871323529411765, 0.9908424908424909, 0.9888888888888889, 0.9966666666666667, 0.99, 0.9903846153846154, 0.9930555555555556, 0.9840764331210191, 0.9906832298136646]
